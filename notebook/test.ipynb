# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
import os

# keys for the services we will use

os.environ["OPENAI_API_KEY"] = "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"
os.environ["GROQ_API_KEY"] = "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"
